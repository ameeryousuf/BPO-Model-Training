# %% [markdown]
# ## 1.0 Train Model

# %%
import json
from pathlib import Path

import numpy as np
import torch
import matplotlib.pyplot as plt
from datasets import Dataset
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from transformers import (
    AutoTokenizer, AutoModelForSequenceClassification,
    TrainingArguments, Trainer, EvalPrediction,
)
from peft import LoraConfig, get_peft_model, TaskType

HEURISTIC_NAMES = ["parallelism", "task_elimination", "task_automation", "task_composition",
                   "case_based_work", "numerical_involvement", "knock_out"]
NUM_LABELS = len(HEURISTIC_NAMES)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 7
#       3
#       4 import numpy as np
#       5 import torch
#       6 import matplotlib.pyplot as plt
# ----> 7 from datasets import Dataset
#       8 from sklearn.metrics import accuracy_score, precision_recall_fscore_support
#       9 from transformers import (
#      10     AutoTokenizer, AutoModelForSequenceClassification,
#
# File ~\anaconda3\envs\sapsam\Lib\site-packages\datasets\__init__.py:17
#       1 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 __version__ = "5.0.1"
# ---> 17 from .arrow_dataset import Column, Dataset
#      18 from .arrow_reader import ReadInstruction
#      19 from .builder import ArrowBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# File ~\anaconda3\envs\sapsam\Lib\site-packages\datasets\arrow_dataset.py:80
#      78 from . import __version__, config
#      79 from .arrow_reader import ArrowReader
# ---> 80 from .arrow_writer import ArrowWriter, OptimizedTypedSequence
#      81 from .data_files import sanitize_patterns
#      82 from .download.streaming_download_manager import xgetsize
#
# File ~\anaconda3\envs\sapsam\Lib\site-packages\datasets\arrow_writer.py:30
#      27 from fsspec.core import url_to_fs
#      29 from . import config
# ---> 30 from .features import Audio, Features, Image, Pdf, Value, Video
#      31 from .features.features import (
#      32     FeatureType,
#      33     List,
#    (...)     42     to_pyarrow_listarray,
#      43 )
#      44 from .filesystems import is_remote_filesystem
#
# File ~\anaconda3\envs\sapsam\Lib\site-packages\datasets\features\__init__.py:23
#       1 __all__ = [
#       2     "Audio",
#       3     "Array2D",
#    (...)     20     "Nifti",
#      21 ]
#      22 from .audio import Audio
# ---> 23 from .features import Array2D, Array3D, Array4D, Array5D, ClassLabel, Features, Json, LargeList, List, Sequence, Value
#      24 from .image import Image
#      25 from .mesh import Mesh
#
# File ~\anaconda3\envs\sapsam\Lib\site-packages\datasets\features\features.py:1191
#    1186         with open(names_filepath, encoding="utf-8") as f:
#    1187             return [name.strip() for name in f.read().split("\n") if name.strip()]  # Filter empty names
#    1190 @dataclass
# -> 1191 class Json:
#    1192     """Feature type for JSON objects.
#    1193
#    1194     Under the hood the objects are stored as JSON-encoded strings.
#    (...)   1223     ```
#    1224     """
#    1226     decode: bool = True
#
# File ~\anaconda3\envs\sapsam\Lib\site-packages\datasets\features\features.py:1229, in Json()
#    1227 id: Optional[str] = field(default=None, repr=False)
#    1228 # Automatically constructed
# -> 1229 pa_type: ClassVar[Any] = pa.json_()
#    1230 _type: str = field(default="Json", init=False, repr=False)
#    1232 def __call__(self):
#
# AttributeError: module 'pyarrow' has no attribute 'json_'
